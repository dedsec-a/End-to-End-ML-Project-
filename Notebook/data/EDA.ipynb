# %%
# Importing all the important Libraries 
import pandas as pd
import numpy as np 
import  matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# Importing the dataset

# %% [markdown]
# Importing the Dataset as Pandas DataFrame

# %%
df= pd.read_csv('stud.csv')
df.head(3)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df.shape # --> Checking the Shape of the DataSet
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # CheckList of the Dataset
# 1. Check Missing Values
# 2. Check Duplicates
# 3. Check Datatypes
# 4. Check the Number of unique values in each column
# 5. check stats of the dataset
# 6. check various categories present in the diffrent categorical column

# %%
# checking the null values
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# There are no Null Values in the given data set

# %%
# checking for the duplicate Values
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicate value in the Given Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# There are 5 Object Type data in the Given Dataset and there is 3 Int Type data in the given  dataset. The total number of data is 8.

# %%
# Checking the Unique Values in the Dataset
# ===============================================
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
# Checking the Stats of the Dataset
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# The mean and the 50 percentile are fairly close to each other , indicating that the distribution is fairly symmetric. The median is 0.5, which is the i.e a normal /  bell curve distribution(Gaussian Distribution). The mean is 0.5, which is the same as the median.
#
# Also that all the mean Values are Close to each other  between 66 to 69
# The Standard devation is also ranging between  0.1 to 0.2 which is also close to each other. This indicates that  the distribution is fairly consistent across the different groups.

# %%
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
num_features = [features for features in df.columns if df[features].dtype  != 'O']
cat_features = [features for features in df.columns if df[features].dtype == 'O']
print(num_features)
print(cat_features)
# Out:
# ['math_score', 'reading_score', 'writing_score']
# ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']

# %%
# Getting the Count of all the unique Values of the catagorical features in the  dataset
print("Count of all the unique Values of the catagorical features in the dataset:")
print("The Number of Features in  Gender    " , end= " ")
print(len(df['gender'].unique()))
print("The Number of unique values in race_ethnicity   " , end= " ")
print(len(df['race_ethnicity'].unique()))
print("The Number of unique values in education   " , end= " ")
print(len(df['parental_level_of_education']))
print("The number of  unique values in lunch  " , end= " " )
print(len(df['lunch'].unique()))
print("The number of Unique Value in test_prepration_course" , end= " ")
print(len(df['test_preparation_course'].unique()))
# Out:
# Count of all the unique Values of the catagorical features in the dataset:
# The Number of Features in  Gender     2
# The Number of unique values in race_ethnicity    5
# The Number of unique values in education    1000
# The number of  unique values in lunch   2
# The number of Unique Value in test_prepration_course 2

# %%
# Adding two New Features to the DataFrame i.e  --> Total Marks and Avrage Marks
df['Total Marks'] = df['math_score'] + df['reading_score'] + df['writing_score']
df['Avrage Marks']  = (df['math_score'] + df['reading_score'] + df['writing_score'])/3
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    Total Marks  Avrage Marks
# 0          218     72.666667
# 1          247     82.333333

# %% [markdown]
# Checking the no of Student with Best Score and Worst Score in the Maths

# %%
reading_full = df[df['reading_score'] == 100].shape[0]
writing_full = df[df['writing_score'] == 100].shape[0]
math_full = df[df['math_score'] == 100].shape[0]


print(f'Number of students with full marks in Maths: {math_full}')
print(f'Number of students with full marks in Writing: {writing_full}')
print(f'Number of students with full marks in Reading: {reading_full}')
# Out:
# Number of students with full marks in Maths: 7
# Number of students with full marks in Writing: 14
# Number of students with full marks in Reading: 17

# %%
reading_low = df[df['reading_score'] <= 20 ].shape[0]
writing_low = df[df['writing_score'] <= 20].shape[0]
maths_low = df[df['math_score'] <= 20].shape[0]

print(f"Number  of students with reading score <= 20: {reading_low}")
print(f"Number of students with full marks in the writing : {writing_full}")
print(f"Number of students with full marks in the maths : {maths_low}")
# Out:
# Number  of students with reading score <= 20: 1
# Number of students with full marks in the writing : 14
# Number of students with full marks in the maths : 4

# %% [markdown]
# #Visualising the Data

# %%
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    Total Marks  Avrage Marks
# 0          218     72.666667
# 1          247     82.333333

# %%
fig , axs = plt.subplots(1,2,figsize= (10,6))
plt.subplot(121)
sns.histplot(data= df , x = 'Avrage Marks' , bins=30 , kde=True , color= 'g')
plt.subplot(122)
sns.histplot(data= df ,  x = 'Avrage Marks' , bins=30 , kde=True , color= 'r' , hue= 'gender')
# Out:
# <Axes: xlabel='Avrage Marks', ylabel='Count'>

# %% [markdown]
# Insight - Female Students Tends to Perform Better than The Male Students

# %%
plt.subplots(1,2 , figsize = (25,6))
plt.subplot(141)
sns.histplot(data= df , x='Avrage Marks' ,  bins = 20 , kde = True , hue= 'lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender == 'female'] , x = 'Avrage Marks' ,  bins= 20 , kde=True , hue='lunch')
plt.subplot(143)
sns.histplot(data= df[df.gender == 'male'] , x=  'Avrage Marks' , bins = 20 , kde=True , hue='lunch')
# Out:
# <Axes: xlabel='Avrage Marks', ylabel='Count'>

# %% [markdown]
# Insights -
# 1. People with the Standard Lunch tend to perfrom better and get good marks as compared to the reduced/free Lunch recivers

# %%
df.head(1)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
#
#    Total Marks  Avrage Marks
# 0          218     72.666667

# %%
# Comparing it to the parental Level of Education 
plt.subplots(1,3 , figsize = (25,6))
plt.subplot(141)
sns.histplot(data= df , x= 'Avrage Marks', bins= 20 , hue= 'parental_level_of_education' , kde=True)
plt.subplot(142)
sns.histplot(data= df[df.gender == 'female'] , x= 'Avrage Marks', bins= 20 ,  hue= 'parental_level_of_education' , kde=True)
plt.subplot(143)
sns.histplot(data= df[df.gender == 'male'], x='Avrage Marks' ,  bins= 20 , hue= 'parental_level_of_education' , kde=True)
# Out:
# <Axes: xlabel='Avrage Marks', ylabel='Count'>

# %% [markdown]
# Insights -
# 1. In General Parents Education doesn't have any real impact on the Education and Score of the Childern
# 2. In the Second Graph it Can be Seen that the children of the Paresnts accosited with bachole's and associate  with them have better score than the children of the parents who are not associated with bachole's

# %%
plt.subplots(1,3 , figsize = (25,6))
plt.subplot(141)
sns.histplot(data= df , x= 'Avrage Marks', bins= 20 , hue= 'race_ethnicity' , kde=True)
plt.subplot(142)
sns.histplot(data= df[df.gender == 'female'] , x= 'Avrage Marks', bins= 20 ,  hue='race_ethnicity' , kde=True)
plt.subplot(143)
sns.histplot(data= df[df.gender == 'male'], x='Avrage Marks' ,  bins= 20 , hue= 'race_ethnicity' , kde=True)
# Out:
# <Axes: xlabel='Avrage Marks', ylabel='Count'>

# %% [markdown]
# Insights
# Group A and Group B are perfroming Bad in Exams irrespective of Anything

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('MATH SCORES')
sns.violinplot(y='math_score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading_score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('WRITING SCORES')
sns.violinplot(y='writing_score',data=df,color='blue',linewidth=3)
plt.show()

# %% [markdown]
# Most of the Students Have Scored Between 50-80 in the Given Plots
# The given plots show that most of the students have scored between 50-80.

# %%
df.head(1)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
#
#    Total Marks  Avrage Marks
# 0          218     72.666667

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['race_ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('race_ethnicity', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['test_preparation_course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 5)
size = df['parental_level_of_education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# #####  Insights
# - Number of Male and Female students is almost equal
# - Number students are greatest in Group C
# - Number of students who have standard lunch are greater
# - Number of students who have not enrolled in any test preparation course is greater
# - Number of students whose parental education is "Some College" is greater followed closely by "Associate's Degree"

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df['gender'],data=df,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df['gender'].value_counts(),labels=['Male','Female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %% [markdown]
# # Checking For OutLiners

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df['math_score'],color='skyblue')
plt.subplot(142)
sns.boxplot(df['reading_score'],color='hotpink')
plt.subplot(143)
sns.boxplot(df['writing_score'],color='yellow')
plt.subplot(144)
sns.boxplot(df['Avrage Marks'],color='lightgreen')
plt.show()

# %%
sns.pairplot(df,hue = 'gender')
plt.show()

# %% [markdown]
# From the Above Score it is Clear that there is a clear Relation Between the given socre and gender and they are positively co-related
